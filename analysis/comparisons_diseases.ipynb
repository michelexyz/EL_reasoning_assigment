# %%
from ELreasoner.resources import parser, formatter, elFactory, gateway_class
from ELreasoner.reasoner import compute_subsumers_of_class
import time

# %%
sushi_ontology_path = "/Users/michele/computer_science/code/Knowlege_Representation_Assigment/analysis/doid.human-disease-ontology.589.owl.xml"

# %%
ontology = parser.parseFile(sushi_ontology_path)

# %%
# get concept names
conceptNames = ontology.getConceptNames()
subsumers_per_concept = dict()
execution_time_per_concept = dict()
number_of_it = 15
for i, conceptName in enumerate(conceptNames):
    if i == number_of_it:
        break
    print(f"Computing subsumers of {formatter.format(conceptName)}")
    start_time = time.perf_counter()
    subsumers = compute_subsumers_of_class(conceptName, ontology)
    end_time = time.perf_counter()
    execution_time_per_concept[formatter.format(conceptName)] = (end_time - start_time)*1000
    subsumers_per_concept[formatter.format(conceptName)] = [formatter.format(subsumer) for subsumer in subsumers]
# Out:
# Computing subsumers of DOID_0080133
# Computing subsumers of DOID_0050715
# Computing subsumers of DOID_0060361
# Computing subsumers of DOID_3078
# Computing subsumers of DOID_5398
# Computing subsumers of DOID_1517
# Computing subsumers of DOID_11338
# Computing subsumers of DOID_0060164
# Computing subsumers of DOID_0060084
# Computing subsumers of DOID_0110510
# Computing subsumers of DOID_0110392
# Computing subsumers of DOID_0110002
# Computing subsumers of DOID_6760
# Computing subsumers of DOID_8618
# Computing subsumers of DOID_3540

# %%
subsumers_per_concept
# Out:
# {'DOID_0080133': ['DOID_0080133',
#   'DOID_655',
#   'DOID_0014667',
#   'DOID_700',
#   'DOID_4'],
#  'DOID_0050715': ['DOID_0050715',
#   'DOID_655',
#   'DOID_0014667',
#   'DOID_0060159',
#   'DOID_9252',
#   'DOID_4',
#   'DOID_14749'],
#  'DOID_0060361': ['DOID_0060361',
#   'DOID_37',
#   'DOID_161',
#   'DOID_3390',
#   'DOID_7',
#   'DOID_4',
#   'DOID_16'],
#  'DOID_3078': ['DOID_3078',
#   'DOID_0050687',
#   'DOID_3070',
#   'DOID_162',
#   'DOID_4',
#   'DOID_3069',
#   'DOID_14566'],
#  'DOID_5398': ['DOID_5398',
#   'DOID_0060084',
#   'DOID_657',
#   'DOID_0060072',
#   'DOID_4',
#   'DOID_14566'],
#  'DOID_1517': ['DOID_1517',
#   'DOID_0050624',
#   'DOID_0060072',
#   'DOID_4610',
#   'DOID_4',
#   'DOID_0060085',
#   'DOID_14566'],
#  'DOID_11338': ['DOID_11338',
#   'DOID_104',
#   'DOID_0050117',
#   'DOID_0050338',
#   'DOID_4'],
#  'DOID_0060164': ['DOID_0060164', 'DOID_150', 'DOID_4737', 'DOID_4'],
#  'DOID_0060084': ['DOID_0060084', 'DOID_0060072', 'DOID_4', 'DOID_14566'],
#  'DOID_0110510': ['DOID_0110510',
#   'DOID_0050155',
#   'DOID_863',
#   'DOID_2742',
#   'DOID_0050563',
#   'DOID_7',
#   'DOID_4',
#   'DOID_0050565'],
#  'DOID_0110392': ['DOID_0110392',
#   'DOID_0050155',
#   'DOID_863',
#   'DOID_1492',
#   'DOID_10584',
#   'DOID_5679',
#   'DOID_7',
#   'DOID_4',
#   'DOID_8466',
#   'DOID_5614'],
#  'DOID_0110002': ['DOID_0110002',
#   'DOID_655',
#   'DOID_0014667',
#   'DOID_0060159',
#   'DOID_9252',
#   'DOID_0060336',
#   'DOID_4'],
#  'DOID_6760': ['DOID_6760',
#   'DOID_162',
#   'DOID_4',
#   'DOID_0050686',
#   'DOID_1324',
#   'DOID_14566',
#   'DOID_0050615'],
#  'DOID_8618': ['DOID_8618',
#   'DOID_162',
#   'DOID_4',
#   'DOID_0050686',
#   'DOID_14566',
#   'DOID_3119'],
#  'DOID_3540': ['DOID_3540',
#   'DOID_3093',
#   'DOID_162',
#   'DOID_3541',
#   'DOID_4',
#   'DOID_0050686',
#   'DOID_3620',
#   'DOID_14566',
#   'DOID_368',
#   'DOID_1319',
#   'DOID_1659']}

# %%
gateway = gateway_class.gateway
elk = gateway.getELKReasoner()
hermit = gateway.getHermiTReasoner()

# %%
ontology = parser.parseFile(sushi_ontology_path)

# %%
ELK_subsumers_per_concept = dict()
Hermit_subsumers_per_concept = dict()
ELK_execution_time_per_concept = dict()
Hermit_execution_time_per_concept = dict()

for i, conceptName in enumerate(conceptNames):
    if i == number_of_it:
        break
    print(f"Computing subsumers of {formatter.format(conceptName)}")
    
    start_time = time.perf_counter()
    elk.setOntology(ontology)
    subsumers = elk.getSubsumers(conceptName)
    end_time = time.perf_counter()
    ELK_execution_time_per_concept[formatter.format(conceptName)] = (end_time - start_time)*1000
    ELK_subsumers_per_concept[formatter.format(conceptName)] = [formatter.format(subsumer) for subsumer in subsumers.toArray()]

    
    
    start_time = time.perf_counter()
    hermit.setOntology(ontology)
    subsumers = hermit.getSubsumers(conceptName)
    end_time = time.perf_counter()
    Hermit_execution_time_per_concept[formatter.format(conceptName)] = (end_time - start_time)*1000
    Hermit_subsumers_per_concept[formatter.format(conceptName)] = [formatter.format(subsumer) for subsumer in subsumers.toArray()]
# Out:
# Computing subsumers of DOID_0080133
# Computing subsumers of DOID_0050715
# Computing subsumers of DOID_0060361
# Computing subsumers of DOID_3078
# Computing subsumers of DOID_5398
# Computing subsumers of DOID_1517
# Computing subsumers of DOID_11338
# Computing subsumers of DOID_0060164
# Computing subsumers of DOID_0060084
# Computing subsumers of DOID_0110510
# Computing subsumers of DOID_0110392
# Computing subsumers of DOID_0110002
# Computing subsumers of DOID_6760
# Computing subsumers of DOID_8618
# Computing subsumers of DOID_3540

# %%
# create new dictionaries with concepts with at least 3 subsumers
ELK_subsumers_per_concept_4 = dict()
Hermit_subsumers_per_concept_4 = dict()
our_subsumers_per_concept_4 = dict()

for concept, subsumers in subsumers_per_concept.items():
    if len(subsumers) >= 4:
        our_subsumers_per_concept_4[concept] = subsumers

for concept, subsumers in ELK_subsumers_per_concept.items():
    if len(subsumers) >= 4:
        ELK_subsumers_per_concept_4[concept] = subsumers

for concept, subsumers in Hermit_subsumers_per_concept.items():
    if len(subsumers) >= 4:
        Hermit_subsumers_per_concept_4[concept] = subsumers

# %%
our_subsumers_per_concept_4
# Out:
# {'Maki': ['NamedSushi', 'Maki', 'Food', 'Sushi'],
#  'KappaMaki': ['NamedSushi',
#   'Maki',
#   'Food',
#   'Sushi',
#   'KappaMaki',
#   'RealJapaneseSushi'],
#  'SashimiTuna': ['NamedSushi',
#   'Food',
#   'Sushi',
#   'SashimiTuna',
#   'Sashimi',
#   'RealJapaneseSushi'],
#  'Sesame': ['Food', 'Sesame', 'Grain', 'SushiIngredient'],
#  'TemakiSake': ['NamedSushi',
#   'Maki',
#   'Food',
#   'Sushi',
#   'TemakiSake',
#   'Temaki',
#   'RealJapaneseSushi'],
#  'Mayonnaise': ['Food', 'Mayonnaise', 'SushiIngredient', 'Sauce'],
#  'Avocado': ['Food', 'Avocado', 'SushiIngredient', 'Fruit'],
#  'SashimiSalmonTuna': ['NamedSushi',
#   'Food',
#   'Sushi',
#   'SashimiSalmonTuna',
#   'Sashimi',
#   'RealJapaneseSushi'],
#  'Beef': ['Food', 'Beef', 'SushiIngredient', 'Meat'],
#  'Temaki': ['NamedSushi', 'Maki', 'Food', 'Sushi', 'Temaki'],
#  'Nigiri': ['NamedSushi', 'Food', 'Sushi', 'Nigiri'],
#  'KaniNigiri': ['NamedSushi', 'Food', 'Sushi', 'Nigiri', 'KaniNigiri'],
#  'SesameSeads': ['Food', 'SesameSeads', 'Grain', 'SushiIngredient'],
#  'TemakiCalifornia': ['NamedSushi',
#   'Maki',
#   'Food',
#   'Sushi',
#   'Temaki',
#   'TemakiCalifornia'],
#  'MaguroNigiri': ['NamedSushi', 'Food', 'Sushi', 'Nigiri', 'MaguroNigiri'],
#  'SakeNigiri': ['NamedSushi', 'Food', 'Sushi', 'Nigiri', 'SakeNigiri'],
#  'Ginger': ['Food', 'Vegetable', 'SushiIngredient', 'Ginger'],
#  'SashimiSake': ['NamedSushi',
#   'Food',
#   'Sushi',
#   'SashimiSake',
#   'Sashimi',
#   'RealJapaneseSushi'],
#  'Chicken': ['Food', 'SushiIngredient', 'Chicken', 'Meat'],
#  'Tobiko': ['Food', 'SushiIngredient', 'Tobiko', 'Fish'],
#  'Sriracha': ['Food',
#   'SushiIngredient',
#   'Sriracha',
#   'SpicyIngredient',
#   'Sauce'],
#  'Tuna': ['Food', 'SushiIngredient', 'Fish', 'Tuna'],
#  'Prawn': ['Food', 'SushiIngredient', 'Fish', 'Prawn'],
#  'TamagoNigiri': ['NamedSushi',
#   'Food',
#   'Sushi',
#   'Nigiri',
#   'TamagoNigiri',
#   'RealJapaneseSushi'],
#  'Cucumber': ['Food', 'Vegetable', 'SushiIngredient', 'Cucumber'],
#  'Sashimi': ['NamedSushi', 'Food', 'Sushi', 'Sashimi'],
#  'Crab': ['Food', 'SushiIngredient', 'Fish', 'Crab'],
#  'Onion': ['Food', 'Vegetable', 'SushiIngredient', 'Onion'],
#  'TemakiMaguro': ['NamedSushi',
#   'Maki',
#   'Food',
#   'Sushi',
#   'Temaki',
#   'TemakiMaguro',
#   'RealJapaneseSushi'],
#  'EbiNigiri': ['NamedSushi', 'Food', 'Sushi', 'Nigiri', 'EbiNigiri'],
#  'Salmon': ['Food', 'SushiIngredient', 'Fish', 'Salmon'],
#  'TemakiMaguroSpicy': ['NamedSushi',
#   'Maki',
#   'Food',
#   'Sushi',
#   'Temaki',
#   'TemakiMaguroSpicy',
#   'RealJapaneseSushi'],
#  'SoySauce': ['Food', 'SushiIngredient', 'SoySauce', 'Sauce'],
#  'RawFishSushi': ['Food', 'Sushi', 'NonVegetarianSushi', 'RawFishSushi'],
#  'Rice': ['Food', 'Grain', 'SushiIngredient', 'Rice']}

# %%
concepts_in_common = list(set(ELK_subsumers_per_concept_4.keys()).intersection(set(Hermit_subsumers_per_concept_4.keys())).intersection(set(our_subsumers_per_concept_4.keys())))

# %%
concepts_in_common
# Out:
# ['DOID_8618',
#  'DOID_0110392',
#  'DOID_3540',
#  'DOID_1517',
#  'DOID_0080133',
#  'DOID_0060361',
#  'DOID_5398',
#  'DOID_0060164',
#  'DOID_0060084',
#  'DOID_0110002',
#  'DOID_11338',
#  'DOID_3078',
#  'DOID_0050715',
#  'DOID_6760',
#  'DOID_0110510']

# %%
#pick 10 concepts in common
import random
random.seed(42)
concepts_in_common_selection = random.sample(concepts_in_common, 10)

# %%
# create a dictionary with the number of subsumers per class

data_EL = dict()
data_ELK = dict()
data_Hermit = dict()

execution_data_EL = dict()
execution_data_ELK = dict()
execution_data_Hermit = dict()

for concept in concepts_in_common_selection:
    data_EL[concept] = len(our_subsumers_per_concept_4[concept])
    data_ELK[concept] = len(ELK_subsumers_per_concept_4[concept])-1 #removing top
    data_Hermit[concept] = len(Hermit_subsumers_per_concept_4[concept])-1 #removing top
    
    execution_data_EL[concept] = execution_time_per_concept[concept]
    execution_data_ELK[concept] = ELK_execution_time_per_concept[concept]
    execution_data_Hermit[concept] = Hermit_execution_time_per_concept[concept]

# %%
import matplotlib.pyplot as plt
import numpy as np

classes = list(data_EL.keys())
bar_width = 0.15 # Width of the bars
index = np.arange(len(classes))  # The x locations for the groups

# Colors in hex
darkish_yellow = '#DAA520'  # Goldenrod
softer_red = '#FF6347'  # Tomato

# Create bars
plt.bar(index, [data_EL[cls] for cls in classes], bar_width,color='blue', label='EL')
plt.bar(index + bar_width, [data_ELK[cls] for cls in classes], bar_width, color=darkish_yellow, label='ELK')
plt.bar(index + 2*bar_width, [data_Hermit[cls] for cls in classes], bar_width, color=softer_red, label='Hermit')

# Add titles and labels
plt.xlabel('Classes')
plt.ylabel('Number of Subsumers')
plt.title('')
plt.xticks(index + bar_width, classes, rotation=45)  # Rotate labels
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

classes = list(execution_data_EL.keys())
bar_width = 0.15 # Width of the bars
index = np.arange(len(classes))  # The x locations for the groups

# Colors in hex
darkish_yellow = '#DAA520'  # Goldenrod
softer_red = '#FF6347'  # Tomato

# Create bars
plt.bar(index, [execution_data_EL[cls] for cls in classes], bar_width,color='blue', label='EL')
plt.bar(index + bar_width, [execution_data_ELK[cls] for cls in classes], bar_width, color=darkish_yellow, label='ELK')
plt.bar(index + 2*bar_width, [execution_data_Hermit[cls] for cls in classes], bar_width, color=softer_red, label='Hermit')

# Add titles and labels
plt.xlabel('Classes')
plt.ylabel('Time in milliseconds')
plt.title('')
plt.xticks(index + bar_width, classes, rotation=45)  # Rotate labels
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Time comparison

# %%
import time


# Your code here

# %%
ontology = parser.parseFile(sushi_ontology_path)

# %%
# get concept names
conceptNames = ontology.getConceptNames()
execution_time_per_concept = dict()

for conceptName in conceptNames:
    print(f"Computing subsumers of {formatter.format(conceptName)}")
    start_time = time.perf_counter()
    subsumers = compute_subsumers_of_class(conceptName, ontology)
    end_time = time.perf_counter()


    # Calculate elapsed time and convert to milliseconds
    elapsed_time_ms = (end_time - start_time) * 1000 
    execution_time_per_concept[formatter.format(conceptName)] = elapsed_time_ms
# Out:
# Computing subsumers of NamedSushi
# Computing subsumers of VegetarianIngredient
# Computing subsumers of Maki
# Computing subsumers of Food
# Computing subsumers of Raw
# Computing subsumers of Vegetable
# Computing subsumers of Sushi
# Computing subsumers of KappaMaki
# Computing subsumers of SashimiTuna
# Computing subsumers of Sesame
# Computing subsumers of TemakiSake
# Computing subsumers of SimpleSushi
# Computing subsumers of Mayonnaise
# Computing subsumers of Mild
# Computing subsumers of Hot
# Computing subsumers of Avocado
# Computing subsumers of SashimiSalmonTuna
# Computing subsumers of Country
# Computing subsumers of NoriSeaweed
# Computing subsumers of Spiciness
# Computing subsumers of Beef
# Computing subsumers of InterestingSushi
# Computing subsumers of Temaki
# Computing subsumers of Nigiri
# Computing subsumers of KaniNigiri
# Computing subsumers of SesameSeads
# Computing subsumers of Grain
# Computing subsumers of TemakiCalifornia
# Computing subsumers of MaguroNigiri
# Computing subsumers of SakeNigiri
# Computing subsumers of NonVegetarianSushi
# Computing subsumers of SushiIngredient
# Computing subsumers of Ginger
# Computing subsumers of SashimiSake
# Computing subsumers of Chicken
# Computing subsumers of Meat
# Computing subsumers of Tobiko
# Computing subsumers of Fish
# Computing subsumers of Sriracha
# Computing subsumers of Medium
# Computing subsumers of {"Japan"^^xsd:string}
# Computing subsumers of Tuna
# Computing subsumers of Prawn
# Computing subsumers of TamagoNigiri
# Computing subsumers of SpicySushi
# Computing subsumers of Cucumber
# Computing subsumers of Egg
# Computing subsumers of Sashimi
# Computing subsumers of SpicyIngredient
# Computing subsumers of Crab
# Computing subsumers of CookingStyle
# Computing subsumers of VegetarianSushi
# Computing subsumers of Onion
# Computing subsumers of {"United States of America"^^xsd:string}
# Computing subsumers of TemakiMaguro
# Computing subsumers of EbiNigiri
# Computing subsumers of IngredientCharacteristic
# Computing subsumers of Fruit
# Computing subsumers of Salmon
# Computing subsumers of TemakiMaguroSpicy
# Computing subsumers of Cooked
# Computing subsumers of SoySauce
# Computing subsumers of RawFishSushi
# Computing subsumers of Sauce
# Computing subsumers of Rice
# Computing subsumers of RealJapaneseSushi

# %%
execution_time_per_concept
# Out:
# {'NamedSushi': 88.779917001375,
#  'VegetarianIngredient': 91.42083399638068,
#  'Maki': 256.3729159955983,
#  'Food': 41.40991700114682,
#  'Raw': 65.74316700425697,
#  'Vegetable': 72.61145799566293,
#  'Sushi': 54.04633400030434,
#  'KappaMaki': 406.9797920019482,
#  'SashimiTuna': 346.9060420029564,
#  'Sesame': 88.00437500030966,
#  'TemakiSake': 562.3522919995594,
#  'SimpleSushi': 85.97591700527119,
#  'Mayonnaise': 72.89716700324789,
#  'Mild': 64.3623750002007,
#  'Hot': 61.704082996584475,
#  'Avocado': 76.33600000553997,
#  'SashimiSalmonTuna': 427.2301669989247,
#  'Country': 63.68629200005671,
#  'NoriSeaweed': 63.525457997457124,
#  'Spiciness': 48.97054199682316,
#  'Beef': 80.18333400104893,
#  'InterestingSushi': 89.1248749976512,
#  'Temaki': 209.73904200218385,
#  'Nigiri': 136.6770830063615,
#  'KaniNigiri': 311.4928329960094,
#  'SesameSeads': 72.63112499640556,
#  'Grain': 62.69970900029875,
#  'TemakiCalifornia': 384.7014589991886,
#  'MaguroNigiri': 306.56995799654396,
#  'SakeNigiri': 228.59320799761917,
#  'NonVegetarianSushi': 86.1389589990722,
#  'SushiIngredient': 51.00883399427403,
#  'Ginger': 77.82437500281958,
#  'SashimiSake': 340.10995899734553,
#  'Chicken': 72.29770800040569,
#  'Meat': 59.36670899973251,
#  'Tobiko': 76.86066700262018,
#  'Fish': 62.14354200346861,
#  'Sriracha': 155.17966599873034,
#  'Medium': 63.5286670003552,
#  '{"Japan"^^xsd:string}': 39.18066700134659,
#  'Tuna': 79.13058400299633,
#  'Prawn': 92.17116700165207,
#  'TamagoNigiri': 370.12474999937695,
#  'SpicySushi': 203.060583997285,
#  'Cucumber': 77.83379199827323,
#  'Egg': 61.918958999740425,
#  'Sashimi': 159.87191699969117,
#  'SpicyIngredient': 299.0632500004722,
#  'Crab': 75.63779100019019,
#  'CookingStyle': 50.80962499778252,
#  'VegetarianSushi': 68.82675000088057,
#  'Onion': 75.91408300504554,
#  '{"United States of America"^^xsd:string}': 42.575125000439584,
#  'TemakiMaguro': 420.50195900083054,
#  'EbiNigiri': 232.20658300124342,
#  'IngredientCharacteristic': 39.468125003622845,
#  'Fruit': 65.79416599561227,
#  'Salmon': 77.54862499859883,
#  'TemakiMaguroSpicy': 471.3869160041213,
#  'Cooked': 62.05266699544154,
#  'SoySauce': 78.57637500273995,
#  'RawFishSushi': 201.58250000531552,
#  'Sauce': 63.909958000294864,
#  'Rice': 78.59820799785666,
#  'RealJapaneseSushi': 143.87841700227}

# %%
conceptNames = ontology.getConceptNames()
ELK_execution_time_per_concept = dict()
Hermit_execution_time_per_concept = dict()
elk = gateway.getELKReasoner() # reset reasoners
hermit = gateway.getHermiTReasoner()


for conceptName in conceptNames:
    
    

    print(f"Computing subsumers of {formatter.format(conceptName)}")
    start_time = time.perf_counter()
    elk.setOntology(ontology)
    subsumers = elk.getSubsumers(conceptName)
    end_time = time.perf_counter()
    elapsed_time_ms = (end_time - start_time) * 1000
    ELK_execution_time_per_concept[formatter.format(conceptName)] = elapsed_time_ms

    start_time = time.perf_counter()
    hermit.setOntology(ontology)
    subsumers = hermit.getSubsumers(conceptName)
    end_time = time.perf_counter()
    elapsed_time_ms = (end_time - start_time) * 1000
    Hermit_execution_time_per_concept[formatter.format(conceptName)] = elapsed_time_ms
# Out:
# Computing subsumers of NamedSushi
# Computing subsumers of VegetarianIngredient
# Computing subsumers of Maki
# Computing subsumers of Food
# Computing subsumers of Raw
# Computing subsumers of Vegetable
# Computing subsumers of Sushi
# Computing subsumers of KappaMaki
# Computing subsumers of SashimiTuna
# Computing subsumers of Sesame
# Computing subsumers of TemakiSake
# Computing subsumers of SimpleSushi
# Computing subsumers of Mayonnaise
# Computing subsumers of Mild
# Computing subsumers of Hot
# Computing subsumers of Avocado
# Computing subsumers of SashimiSalmonTuna
# Computing subsumers of Country
# Computing subsumers of NoriSeaweed
# Computing subsumers of Spiciness
# Computing subsumers of Beef
# Computing subsumers of InterestingSushi
# Computing subsumers of Temaki
# Computing subsumers of Nigiri
# Computing subsumers of KaniNigiri
# Computing subsumers of SesameSeads
# Computing subsumers of Grain
# Computing subsumers of TemakiCalifornia
# Computing subsumers of MaguroNigiri
# Computing subsumers of SakeNigiri
# Computing subsumers of NonVegetarianSushi
# Computing subsumers of SushiIngredient
# Computing subsumers of Ginger
# Computing subsumers of SashimiSake
# Computing subsumers of Chicken
# Computing subsumers of Meat
# Computing subsumers of Tobiko
# Computing subsumers of Fish
# Computing subsumers of Sriracha
# Computing subsumers of Medium
# Computing subsumers of {"Japan"^^xsd:string}
# Computing subsumers of Tuna
# Computing subsumers of Prawn
# Computing subsumers of TamagoNigiri
# Computing subsumers of SpicySushi
# Computing subsumers of Cucumber
# Computing subsumers of Egg
# Computing subsumers of Sashimi
# Computing subsumers of SpicyIngredient
# Computing subsumers of Crab
# Computing subsumers of CookingStyle
# Computing subsumers of VegetarianSushi
# Computing subsumers of Onion
# Computing subsumers of {"United States of America"^^xsd:string}
# Computing subsumers of TemakiMaguro
# Computing subsumers of EbiNigiri
# Computing subsumers of IngredientCharacteristic
# Computing subsumers of Fruit
# Computing subsumers of Salmon
# Computing subsumers of TemakiMaguroSpicy
# Computing subsumers of Cooked
# Computing subsumers of SoySauce
# Computing subsumers of RawFishSushi
# Computing subsumers of Sauce
# Computing subsumers of Rice
# Computing subsumers of RealJapaneseSushi

# %%
ELK_execution_time_per_concept
# Out:
# {'NamedSushi': 3.230208996683359,
#  'VegetarianIngredient': 2.652124996529892,
#  'Maki': 4.16754100297112,
#  'Food': 2.834833001543302,
#  'Raw': 2.6485000053071417,
#  'Vegetable': 3.2004579989006743,
#  'Sushi': 2.8247919981367886,
#  'KappaMaki': 2.9821669959346764,
#  'SashimiTuna': 3.4141249998356216,
#  'Sesame': 2.8988339981879108,
#  'TemakiSake': 2.9654169993591495,
#  'SimpleSushi': 2.58791699889116,
#  'Mayonnaise': 2.5702089988044463,
#  'Mild': 2.747790997091215,
#  'Hot': 2.8083329962100834,
#  'Avocado': 2.935875003458932,
#  'SashimiSalmonTuna': 2.8841249950346537,
#  'Country': 2.515000000130385,
#  'NoriSeaweed': 2.693915994314011,
#  'Spiciness': 2.6335419970564544,
#  'Beef': 3.0553749966202304,
#  'InterestingSushi': 2.4666250028531067,
#  'Temaki': 2.486292003595736,
#  'Nigiri': 2.8076660018996336,
#  'KaniNigiri': 2.713125002628658,
#  'SesameSeads': 2.6712499966379255,
#  'Grain': 2.6635419999365695,
#  'TemakiCalifornia': 2.6506249996600673,
#  'MaguroNigiri': 2.5459999960730784,
#  'SakeNigiri': 2.5049579999176785,
#  'NonVegetarianSushi': 2.8741659989464097,
#  'SushiIngredient': 2.6004159954027273,
#  'Ginger': 2.4903749945224263,
#  'SashimiSake': 2.7169999957550317,
#  'Chicken': 2.7820000032079406,
#  'Meat': 2.743791999819223,
#  'Tobiko': 2.917500001785811,
#  'Fish': 2.6841669969144277,
#  'Sriracha': 2.8516250022221357,
#  'Medium': 2.73041599575663,
#  '{"Japan"^^xsd:string}': 2.480792005371768,
#  'Tuna': 2.4195410005631857,
#  'Prawn': 2.83033300365787,
#  'TamagoNigiri': 2.503999996406492,
#  'SpicySushi': 2.4478749983245507,
#  'Cucumber': 2.471624997269828,
#  'Egg': 3.7645420015905984,
#  'Sashimi': 2.54875000246102,
#  'SpicyIngredient': 3.0790419987170026,
#  'Crab': 2.777291003440041,
#  'CookingStyle': 2.981332996569108,
#  'VegetarianSushi': 2.568458003224805,
#  'Onion': 2.809584002534393,
#  '{"United States of America"^^xsd:string}': 2.7107909991173074,
#  'TemakiMaguro': 2.8738749970216304,
#  'EbiNigiri': 3.0037079995963722,
#  'IngredientCharacteristic': 3.3762500024749897,
#  'Fruit': 2.8496249942691065,
#  'Salmon': 3.030625004612375,
#  'TemakiMaguroSpicy': 2.9743330014753155,
#  'Cooked': 2.572500001406297,
#  'SoySauce': 2.7729580033337697,
#  'RawFishSushi': 3.049541999644134,
#  'Sauce': 3.133166996121872,
#  'Rice': 2.8217500002938323,
#  'RealJapaneseSushi': 2.789165999274701}
